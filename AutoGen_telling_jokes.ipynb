# %%
pip install -q pyautogen
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 23.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.6/320.6 kB 20.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.9 MB/s eta 0:00:00

# %%
# only for Google Colab; please comment Kaggle part in this case
from google.colab import userdata
openai_api_key = userdata.get('OPENAI_API_KEY')

# only for Kaggle; please comment Google Colab part in this case
#from kaggle_secrets import UserSecretsClient
#user_secrets = UserSecretsClient()
#openai_api_key = user_secrets.get_secret("OPENAI_API_KEY")

# %%
import os
from autogen import AssistantAgent, UserProxyAgent

llm_config = {"model": "gpt-4", "api_key": openai_api_key}
assistant = AssistantAgent("assistant", llm_config=llm_config)
user_proxy = UserProxyAgent("user_proxy", code_execution_config=False)

# Start the chat
user_proxy.initiate_chat(
    assistant,
    message="Tell me a joke about NVDA and TESLA stock prices.",
)
# Out:
# user_proxy (to assistant):
#
# Tell me a joke about NVDA and TESLA stock prices.
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# Why don't we let Python do the talking? Here's a script that'll crack you a joke about NVDA (NVIDIA Corporation) and TESLA stocks.
#
# ```python
# import yfinance as yf
#
# # Fetch data
# nvda = yf.Ticker("NVDA")
# tesla = yf.Ticker("TSLA")
#
# # Get the latest close price
# nvda_price = nvda.info['previousClose']
# tesla_price = tesla.info['previousClose']
#
# # Here comes the joke
# joke = "Why did the stock market invite NVDA and TESLA to the party? \nBecause whenever they appear, they make things go up and down like a dance floor!"
#
# # Adding a punchline based on the prices.
# if nvda_price > tesla_price:
#     punch_line = f"Especially NVDA, it's currently standing tall at {nvda_price} overshadowing TESLA at {tesla_price}!"
# else:
#     punch_line = f"Especially TESLA, it's currently zooming away at {tesla_price} leaving behind NVDA at {nvda_price}!"
#
# print(joke)
# print(punch_line)
# ```
# Note:
# 1. This script uses the yfinance library, which needs to be installed. Please use pip (or pip3 for python3) install yfinance if it is not installed.
# 2. The stock prices are closing prices and are real-time data. This joke will make sense only during trading hours.
#
# --------------------------------------------------------------------------------
# Provide feedback to assistant. Press enter to skip and use auto-reply, or type 'exit' to end the conversation: exit
# ChatResult(chat_id=None, chat_history=[{'content': 'Tell me a joke about NVDA and TESLA stock prices.', 'role': 'assistant'}, {'content': 'Why don\'t we let Python do the talking? Here\'s a script that\'ll crack you a joke about NVDA (NVIDIA Corporation) and TESLA stocks. \n\n```python\nimport yfinance as yf\n\n# Fetch data\nnvda = yf.Ticker("NVDA")\ntesla = yf.Ticker("TSLA")\n\n# Get the latest close price\nnvda_price = nvda.info[\'previousClose\']\ntesla_price = tesla.info[\'previousClose\']\n\n# Here comes the joke\njoke = "Why did the stock market invite NVDA and TESLA to the party? \\nBecause whenever they appear, they make things go up and down like a dance floor!"\n\n# Adding a punchline based on the prices.\nif nvda_price > tesla_price:\n    punch_line = f"Especially NVDA, it\'s currently standing tall at {nvda_price} overshadowing TESLA at {tesla_price}!"\nelse:\n    punch_line = f"Especially TESLA, it\'s currently zooming away at {tesla_price} leaving behind NVDA at {nvda_price}!"\n    \nprint(joke)\nprint(punch_line)\n```\nNote: \n1. This script uses the yfinance library, which needs to be installed. Please use pip (or pip3 for python3) install yfinance if it is not installed. \n2. The stock prices are closing prices and are real-time data. This joke will make sense only during trading hours.', 'role': 'user'}], summary='Why don\'t we let Python do the talking? Here\'s a script that\'ll crack you a joke about NVDA (NVIDIA Corporation) and TESLA stocks. \n\n```python\nimport yfinance as yf\n\n# Fetch data\nnvda = yf.Ticker("NVDA")\ntesla = yf.Ticker("TSLA")\n\n# Get the latest close price\nnvda_price = nvda.info[\'previousClose\']\ntesla_price = tesla.info[\'previousClose\']\n\n# Here comes the joke\njoke = "Why did the stock market invite NVDA and TESLA to the party? \\nBecause whenever they appear, they make things go up and down like a dance floor!"\n\n# Adding a punchline based on the prices.\nif nvda_price > tesla_price:\n    punch_line = f"Especially NVDA, it\'s currently standing tall at {nvda_price} overshadowing TESLA at {tesla_price}!"\nelse:\n    punch_line = f"Especially TESLA, it\'s currently zooming away at {tesla_price} leaving behind NVDA at {nvda_price}!"\n    \nprint(joke)\nprint(punch_line)\n```\nNote: \n1. This script uses the yfinance library, which needs to be installed. Please use pip (or pip3 for python3) install yfinance if it is not installed. \n2. The stock prices are closing prices and are real-time data. This joke will make sense only during trading hours.', cost={'usage_including_cached_inference': {'total_cost': 0.033299999999999996, 'gpt-4-0613': {'cost': 0.033299999999999996, 'prompt_tokens': 486, 'completion_tokens': 312, 'total_tokens': 798}}, 'usage_excluding_cached_inference': {'total_cost': 0.033299999999999996, 'gpt-4-0613': {'cost': 0.033299999999999996, 'prompt_tokens': 486, 'completion_tokens': 312, 'total_tokens': 798}}}, human_input=['exit'])
