# %% [markdown]
# <a href="https://colab.research.google.com/github/cojocarucosmin/AICourseDev/blob/main/Complex_sub-queries_with_llamaindex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Complex subqueries with website info and decomposition analysis
# In this demo, we explore answering complex queries by decomposing them into simpler sub-queries.

# %%
# !pip install -q llama-index-llms-openai llama-index

# %%
import os
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, Settings
from llama_index.llms.openai import OpenAI
from llama_index.readers.web import SimpleWebPageReader
from llama_index.readers.remote import RemoteReader

from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.core.query_engine import SubQuestionQueryEngine

import nest_asyncio

nest_asyncio.apply()

# %% [markdown]
# ## Configure LLM service

# %%
# only for Google Colab; please comment Kaggle part in this case
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# %%
Settings.llm = OpenAI(temperature=0.2, model="gpt-4o")

# %% [markdown]
# ## Loading and queryeing a web page

# %%
reader = SimpleWebPageReader(html_to_text=True)
docs = reader.load_data(urls=["https://en.wikipedia.org/wiki/Uber", "https://en.wikipedia.org/wiki/Lyft"])

# %%
# index & query
index = VectorStoreIndex.from_documents(docs)
query_engine = index.as_query_engine()
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
print(query_engine.query("Where is Uber located?").response)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Uber is located in San Francisco, California.

# %%
print(query_engine.query("Where is Lyft located?").response)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Lyft operates in the United States and Canada.

# %% [markdown]
# ## Read documents directly from webpage

# %%
loader = RemoteReader()

uber_docs = loader.load_data(url="https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10k/uber_2021.pdf")
lyft_docs = loader.load_data(url="https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10k/lyft_2021.pdf")

# %% [markdown]
# ## Download & read documents

# %%
# !mkdir -p 'data/10k/'
# !wget 'https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10k/uber_2021.pdf' -O 'data/10k/uber_2021.pdf'
# !wget 'https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10k/lyft_2021.pdf' -O 'data/10k/lyft_2021.pdf'
# Out:
# --2025-07-01 23:00:54--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10k/uber_2021.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1880483 (1.8M) [application/octet-stream]
# Saving to: ‘data/10k/uber_2021.pdf’
#
# data/10k/uber_2021. 100%[===================>]   1.79M  --.-KB/s    in 0.07s
#
# 2025-07-01 23:00:54 (27.1 MB/s) - ‘data/10k/uber_2021.pdf’ saved [1880483/1880483]
#
# --2025-07-01 23:00:54--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10k/lyft_2021.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
lyft_docs = SimpleDirectoryReader(input_files=["./data/10k/lyft_2021.pdf"]).load_data()
uber_docs = SimpleDirectoryReader(input_files=["./data/10k/uber_2021.pdf"]).load_data()

# %% [markdown]
# ## Build indices

# %%
lyft_index = VectorStoreIndex.from_documents(lyft_docs)
uber_index = VectorStoreIndex.from_documents(uber_docs)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %% [markdown]
# ## Build query engines

# %%
lyft_engine = lyft_index.as_query_engine(similarity_top_k=3)
uber_engine = uber_index.as_query_engine(similarity_top_k=3)

# %%
query_engine_tools = [
    QueryEngineTool(
        query_engine=lyft_engine,
        metadata=ToolMetadata(
            name="lyft_10k",
            description=(
                "Provides information about Lyft financials for year 2021"
            ),
        ),
    ),
    QueryEngineTool(
        query_engine=uber_engine,
        metadata=ToolMetadata(
            name="uber_10k",
            description=(
                "Provides information about Uber financials for year 2021"
            ),
        ),
    ),
]

s_engine = SubQuestionQueryEngine.from_defaults(
    query_engine_tools=query_engine_tools
)

# %% [markdown]
# ## Run queries

# %%
response = s_engine.query(
    "Compare and contrast the customer segments and geographies that grew the fastest"
)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Generated 4 sub questions.
# [lyft_10k] Q: What were the fastest growing customer segments for Lyft in 2021?
# [lyft_10k] Q: What were the fastest growing geographies for Lyft in 2021?
# [uber_10k] Q: What were the fastest growing customer segments for Uber in 2021?
# [uber_10k] Q: What were the fastest growing geographies for Uber in 2021?
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...

# %%
response.response
# Out:
# 'In 2021, Uber experienced significant growth in its customer segments related to its Delivery services, driven by increased demand for meal, grocery, alcohol, and convenience store deliveries. This growth was further supported by the introduction of Uber One, a membership program offering discounts and perks. Unfortunately, there is no specific information available about the fastest growing customer segments for Lyft or the fastest growing geographies for either company in 2021.'

# %%
response = s_engine.query(
    "Compare revenue growth of Uber and Lyft from 2020 to 2021"
)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:openai._base_client:Retrying request to /embeddings in 0.449643 seconds
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Generated 4 sub questions.
# [lyft_10k] Q: What was Lyft's revenue in 2020?
# [lyft_10k] Q: What was Lyft's revenue in 2021?
# [uber_10k] Q: What was Uber's revenue in 2020?
# [uber_10k] Q: What was Uber's revenue in 2021?
# INFO:openai._base_client:Retrying request to /chat/completions in 0.460075 seconds
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...

# %%
response.response
# Out:
# "From 2020 to 2021, Lyft's revenue increased from $2,364,681,000 to $3,208,323,000, which represents a growth of approximately 35.7%. During the same period, Uber's revenue grew from $11,139 million to $17,455 million, marking an increase of about 56.7%. Therefore, Uber experienced a higher revenue growth rate compared to Lyft between 2020 and 2021."
