# %% [markdown]
# <a href="https://colab.research.google.com/github/cojocarucosmin/AICourseDev/blob/main/Open_deep_researcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Open Deep Researcher**

# %%
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)

# %%
import asyncio
import aiohttp
import json
from google.colab import userdata

# =======================
# Configuration Constants
# =======================
OPENROUTER_API_KEY = userdata.get('OPENROUTER_API_KEY')
SERPAPI_API_KEY    = userdata.get("SERPAPI_API_KEY")
JINA_API_KEY       = userdata.get("JINA_API_KEY")

# Endpoints
OPENROUTER_URL = "https://openrouter.ai/api/v1/chat/completions"
SERPAPI_URL = "https://serpapi.com/search"
JINA_BASE_URL = "https://r.jina.ai/"

# Default LLM model (can be changed if desired)
DEFAULT_MODEL = "anthropic/claude-3.5-haiku"

# ============================
# Asynchronous Helper Functions
# ============================

async def call_openrouter_async(session, messages, model=DEFAULT_MODEL):
    """
    Asynchronously call the OpenRouter chat completion API with the provided messages.
    Returns the content of the assistant’s reply.
    """
    headers = {
        "Authorization": f"Bearer {OPENROUTER_API_KEY}",
        "X-Title": "OpenDeepResearcher, by Matt Shumer",
        "Content-Type": "application/json"
    }
    payload = {
        "model": model,
        "messages": messages
    }
    try:
        async with session.post(OPENROUTER_URL, headers=headers, json=payload) as resp:
            if resp.status == 200:
                result = await resp.json()
                try:
                    return result['choices'][0]['message']['content']
                except (KeyError, IndexError) as e:
                    print("Unexpected OpenRouter response structure:", result)
                    return None
            else:
                text = await resp.text()
                print(f"OpenRouter API error: {resp.status} - {text}")
                return None
    except Exception as e:
        print("Error calling OpenRouter:", e)
        return None


async def generate_search_queries_async(session, user_query):
    """
    Ask the LLM to produce up to four precise search queries (in Python list format)
    based on the user’s query.
    """
    prompt = (
        "You are an expert research assistant. Given the user's query, generate up to four distinct, "
        "precise search queries that would help gather comprehensive information on the topic. "
        "Return only a Python list of strings, for example: ['query1', 'query2', 'query3']."
    )
    messages = [
        {"role": "system", "content": "You are a helpful and precise research assistant."},
        {"role": "user", "content": f"User Query: {user_query}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        try:
            # Expect exactly a Python list (e.g., "['query1', 'query2']")
            search_queries = eval(response)
            if isinstance(search_queries, list):
                return search_queries
            else:
                print("LLM did not return a list. Response:", response)
                return []
        except Exception as e:
            print("Error parsing search queries:", e, "\nResponse:", response)
            return []
    return []


async def perform_search_async(session, query):
    """
    Asynchronously perform a Google search using SERPAPI for the given query.
    Returns a list of result URLs.
    """
    params = {
        "q": query,
        "api_key": SERPAPI_API_KEY,
        "engine": "google"
    }
    try:
        async with session.get(SERPAPI_URL, params=params) as resp:
            if resp.status == 200:
                results = await resp.json()
                if "organic_results" in results:
                    links = [item.get("link") for item in results["organic_results"] if "link" in item]
                    return links
                else:
                    print("No organic results in SERPAPI response.")
                    return []
            else:
                text = await resp.text()
                print(f"SERPAPI error: {resp.status} - {text}")
                return []
    except Exception as e:
        print("Error performing SERPAPI search:", e)
        return []


async def fetch_webpage_text_async(session, url):
    """
    Asynchronously retrieve the text content of a webpage using Jina.
    The URL is appended to the Jina endpoint.
    """
    full_url = f"{JINA_BASE_URL}{url}"
    headers = {
        "Authorization": f"Bearer {JINA_API_KEY}"
    }
    try:
        async with session.get(full_url, headers=headers) as resp:
            if resp.status == 200:
                return await resp.text()
            else:
                text = await resp.text()
                print(f"Jina fetch error for {url}: {resp.status} - {text}")
                return ""
    except Exception as e:
        print("Error fetching webpage text with Jina:", e)
        return ""


async def is_page_useful_async(session, user_query, page_text):
    """
    Ask the LLM if the provided webpage content is useful for answering the user's query.
    The LLM must reply with exactly "Yes" or "No".
    """
    prompt = (
        "You are a critical research evaluator. Given the user's query and the content of a webpage, "
        "determine if the webpage contains information relevant and useful for addressing the query. "
        "Respond with exactly one word: 'Yes' if the page is useful, or 'No' if it is not. Do not include any extra text."
    )
    messages = [
        {"role": "system", "content": "You are a strict and concise evaluator of research relevance."},
        {"role": "user", "content": f"User Query: {user_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        answer = response.strip()
        if answer in ["Yes", "No"]:
            return answer
        else:
            # Fallback: try to extract Yes/No from the response.
            if "Yes" in answer:
                return "Yes"
            elif "No" in answer:
                return "No"
    return "No"


async def extract_relevant_context_async(session, user_query, search_query, page_text):
    """
    Given the original query, the search query used, and the page content,
    have the LLM extract all information relevant for answering the query.
    """
    prompt = (
        "You are an expert information extractor. Given the user's query, the search query that led to this page, "
        "and the webpage content, extract all pieces of information that are relevant to answering the user's query. "
        "Return only the relevant context as plain text without commentary."
    )
    messages = [
        {"role": "system", "content": "You are an expert in extracting and summarizing relevant information."},
        {"role": "user", "content": f"User Query: {user_query}\nSearch Query: {search_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        return response.strip()
    return ""


async def get_new_search_queries_async(session, user_query, previous_search_queries, all_contexts):
    """
    Based on the original query, the previously used search queries, and all the extracted contexts,
    ask the LLM whether additional search queries are needed. If yes, return a Python list of up to four queries;
    if the LLM thinks research is complete, it should return "<done>".
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an analytical research assistant. Based on the original query, the search queries performed so far, "
        "and the extracted contexts from webpages, determine if further research is needed. "
        "If further research is needed, provide up to four new search queries as a Python list (for example, "
        "['new query1', 'new query2']). If you believe no further research is needed, respond with exactly <done>."
        "\nOutput only a Python list or the token <done> without any additional text."
    )
    messages = [
        {"role": "system", "content": "You are a systematic research planner."},
        {"role": "user", "content": f"User Query: {user_query}\nPrevious Search Queries: {previous_search_queries}\n\nExtracted Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        cleaned = response.strip()
        if cleaned == "<done>":
            return "<done>"
        try:
            new_queries = eval(cleaned)
            if isinstance(new_queries, list):
                return new_queries
            else:
                print("LLM did not return a list for new search queries. Response:", response)
                return []
        except Exception as e:
            print("Error parsing new search queries:", e, "\nResponse:", response)
            return []
    return []


async def generate_final_report_async(session, user_query, all_contexts):
    """
    Generate the final comprehensive report using all gathered contexts.
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an expert researcher and report writer. Based on the gathered contexts below and the original query, "
        "write a comprehensive, well-structured, and detailed report that addresses the query thoroughly. "
        "Include all relevant insights and conclusions without extraneous commentary."
    )
    messages = [
        {"role": "system", "content": "You are a skilled report writer."},
        {"role": "user", "content": f"User Query: {user_query}\n\nGathered Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    report = await call_openrouter_async(session, messages)
    return report


async def process_link(session, link, user_query, search_query):
    """
    Process a single link: fetch its content, judge its usefulness, and if useful, extract the relevant context.
    """
    print(f"Fetching content from: {link}")
    page_text = await fetch_webpage_text_async(session, link)
    if not page_text:
        return None
    usefulness = await is_page_useful_async(session, user_query, page_text)
    print(f"Page usefulness for {link}: {usefulness}")
    if usefulness == "Yes":
        context = await extract_relevant_context_async(session, user_query, search_query, page_text)
        if context:
            print(f"Extracted context from {link} (first 200 chars): {context[:200]}")
            return context
    return None


# =========================
# Main Asynchronous Routine
# =========================

async def async_main():
    user_query = input("Enter your research query/topic: ").strip()
    iter_limit_input = input("Enter maximum number of iterations (default 10): ").strip()
    iteration_limit = int(iter_limit_input) if iter_limit_input.isdigit() else 10

    aggregated_contexts = []    # All useful contexts from every iteration
    all_search_queries = []     # Every search query used across iterations
    iteration = 0

    async with aiohttp.ClientSession() as session:
        # ----- INITIAL SEARCH QUERIES -----
        new_search_queries = await generate_search_queries_async(session, user_query)
        if not new_search_queries:
            print("No search queries were generated by the LLM. Exiting.")
            return
        all_search_queries.extend(new_search_queries)

        # ----- ITERATIVE RESEARCH LOOP -----
        while iteration < iteration_limit:
            print(f"\n=== Iteration {iteration + 1} ===")
            iteration_contexts = []

            # For each search query, perform SERPAPI searches concurrently.
            search_tasks = [perform_search_async(session, query) for query in new_search_queries]
            search_results = await asyncio.gather(*search_tasks)

            # Aggregate all unique links from all search queries of this iteration.
            # Map each unique link to the search query that produced it.
            unique_links = {}
            for idx, links in enumerate(search_results):
                query = new_search_queries[idx]
                for link in links:
                    if link not in unique_links:
                        unique_links[link] = query

            print(f"Aggregated {len(unique_links)} unique links from this iteration.")

            # Process each link concurrently: fetch, judge, and extract context.
            link_tasks = [
                process_link(session, link, user_query, unique_links[link])
                for link in unique_links
            ]
            link_results = await asyncio.gather(*link_tasks)

            # Collect non-None contexts.
            for res in link_results:
                if res:
                    iteration_contexts.append(res)

            if iteration_contexts:
                aggregated_contexts.extend(iteration_contexts)
            else:
                print("No useful contexts were found in this iteration.")

            # ----- ASK THE LLM IF MORE SEARCHES ARE NEEDED -----
            new_search_queries = await get_new_search_queries_async(session, user_query, all_search_queries, aggregated_contexts)
            if new_search_queries == "<done>":
                print("LLM indicated that no further research is needed.")
                break
            elif new_search_queries:
                print("LLM provided new search queries:", new_search_queries)
                all_search_queries.extend(new_search_queries)
            else:
                print("LLM did not provide any new search queries. Ending the loop.")
                break

            iteration += 1

        # ----- FINAL REPORT -----
        print("\nGenerating final report...")
        final_report = await generate_final_report_async(session, user_query, aggregated_contexts)
        print("\n==== FINAL REPORT ====\n")
        print(final_report)


def main():
    asyncio.run(async_main())


if __name__ == "__main__":
    main()
# Out:
# Enter your research query/topic: Analyze Sostenia products
# Enter maximum number of iterations (default 10): 2
#
# === Iteration 1 ===
# Aggregated 31 unique links from this iteration.
# Fetching content from: https://www.odoo.com/pt_BR/customers/sostenia-srl-5350747
# Fetching content from: https://www.sostenia.ro/en/aplicatii-software-sostenia
# Fetching content from: https://www.sostenia.ro/shop
# Fetching content from: https://sosteneo.com/
# Fetching content from: https://www.renewablethermal.org/
# Fetching content from: https://sabo.com/products-and-applications/
# Fetching content from: https://www.webuildgroup.com/en/
# Fetching content from: https://www.dotdashmeredith.com/
# Fetching content from: https://about.deere.com/en-us/us-impact
# Fetching content from: https://www.odoo.com/ro_RO/customers/sostenia-s-r-l-5350747
# Fetching content from: https://www.sostenia.ro/en/blog/sostenia-blog-1/maximize-the-benefits-of-digitization-funds-51
# Fetching content from: https://www.sostenia.ro/en
# Fetching content from: https://heysoteria.com/
# Fetching content from: https://www.odoo.com/th_TH/customers/sostenia-s-r-l-5350747
# Fetching content from: https://www.linkedin.com/posts/sumanyu-ghoshal_we-at-prodigal-hosted-our-first-ai-event-activity-7248917073853112320--Cq1
# Fetching content from: https://www.linkedin.com/posts/marcvillari_odoo-odoo-gotechworld-activity-7257752454568497153-JH4E
# Fetching content from: https://www.risco.ro/en/verifica-firma/sostenia-cui-35130445?srsltid=AfmBOooisspI3vHrdg4PcklWHcNPpc_vJob_axtkukYudl6vL7GxEdxh
# Fetching content from: https://www.odoocompanies.com/c-sostenia-srl
# Fetching content from: https://www.facebook.com/archangelmichaelgoc/videos/live/949674730499866/
# Fetching content from: https://www.sostenia.ro/en/home
# Fetching content from: https://www.odoo.com/customers/sostenia-srl-5350747
# Fetching content from: https://www.sostenia.ro/en/slides/slide/modul-website-odoo-6?fullscreen=1
# Fetching content from: https://www.linkedin.com/posts/sostenia_salesrepresentative-salesopening-activity-7289938221893877761-WVrL
# Fetching content from: https://www.youtube.com/watch?v=KYDFLOjBPLY
# Fetching content from: https://www.lusha.com/business/4ac190c47bc10459/
# Fetching content from: https://techvify.com/what-is-enterprise-software/
# Fetching content from: https://amazon.jobs/it/jobs/2985074/sr-software-development-engineer-alexa-enterprise-products-aep-alexa-enterprise-products
# Fetching content from: https://www.dnb.com/business-directory/company-profiles.sostenia_soc_coop.aff0cc053537f4ca0a02254053f112d4.html
# Fetching content from: https://www.dnb.com/business-directory/company-profiles.sostenia_srl.73521df5d458486020c88ff2e136c7a7.html
# Fetching content from: https://www.emis.com/php/company-profile/RO/Sostenia_SRL_en_14148987.html
# Fetching content from: https://italy.globaldatabase.com/company/sostenia-soc-coop
# Page usefulness for https://www.dotdashmeredith.com/: No
# Page usefulness for https://www.renewablethermal.org/: No
# Page usefulness for https://sosteneo.com/: No
# Page usefulness for https://www.lusha.com/business/4ac190c47bc10459/: Yes
# Page usefulness for https://www.odoo.com/pt_BR/customers/sostenia-srl-5350747: Yes
# Page usefulness for https://www.linkedin.com/posts/sostenia_salesrepresentative-salesopening-activity-7289938221893877761-WVrL: No
# Page usefulness for https://italy.globaldatabase.com/company/sostenia-soc-coop: Yes
# Page usefulness for https://www.odoo.com/ro_RO/customers/sostenia-s-r-l-5350747: Yes
# Page usefulness for https://www.sostenia.ro/en/home: Yes
# Page usefulness for https://www.odoo.com/th_TH/customers/sostenia-s-r-l-5350747: Yes
# Page usefulness for https://www.sostenia.ro/en/slides/slide/modul-website-odoo-6?fullscreen=1: No
# Page usefulness for https://www.sostenia.ro/en/blog/sostenia-blog-1/maximize-the-benefits-of-digitization-funds-51: No
# Page usefulness for https://www.odoocompanies.com/c-sostenia-srl: Yes
# Page usefulness for https://www.linkedin.com/posts/sumanyu-ghoshal_we-at-prodigal-hosted-our-first-ai-event-activity-7248917073853112320--Cq1: No
# Page usefulness for https://www.sostenia.ro/shop: Yes
# Page usefulness for https://www.linkedin.com/posts/marcvillari_odoo-odoo-gotechworld-activity-7257752454568497153-JH4E: No
# Page usefulness for https://www.odoo.com/customers/sostenia-srl-5350747: Yes
# Page usefulness for https://heysoteria.com/: Yes
# Page usefulness for https://www.youtube.com/watch?v=KYDFLOjBPLY: No
# Page usefulness for https://www.webuildgroup.com/en/: No
# Extracted context from https://italy.globaldatabase.com/company/sostenia-soc-coop (first 200 chars): Based on the available information, here are the key details about Sostenia:
#
# Company Details:
# - Full Name: SOSTENIA SOC. COOP.
# - Location: VIA VINA, 49, Italy
# - Contact Phone: +390941******
# - Number
# Page usefulness for https://www.sostenia.ro/en/aplicatii-software-sostenia: Yes
# Extracted context from https://www.odoo.com/ro_RO/customers/sostenia-s-r-l-5350747 (first 200 chars): Based on the webpage content, here are the key details about Sostenia's products and technology offerings:
#
# Sostenia is a specialized software company focused on digital transformation, with the follo
# Page usefulness for https://www.sostenia.ro/en: Yes
# Extracted context from https://www.lusha.com/business/4ac190c47bc10459/ (first 200 chars): Based on the webpage content, here are the key details about Sostenia's products and services:
#
# Sostenia is a software development company specializing in digital transformation and business process i
# Page usefulness for https://about.deere.com/en-us/us-impact: No
# Page usefulness for https://sabo.com/products-and-applications/: No
# Extracted context from https://www.odoo.com/pt_BR/customers/sostenia-srl-5350747 (first 200 chars): Based on the webpage content, here are the key details about Sostenia's products and services:
#
# Sostenia is a specialized software company focused on Digital Transformation, offering the following pro
# Page usefulness for https://techvify.com/what-is-enterprise-software/: No
# Page usefulness for https://amazon.jobs/it/jobs/2985074/sr-software-development-engineer-alexa-enterprise-products-aep-alexa-enterprise-products: No
# Extracted context from https://www.sostenia.ro/en/home (first 200 chars): Based on the webpage content, here are the key details about Sostenia's products and services:
#
# Sostenia offers enterprise digital transformation solutions, with a focus on:
#
# 1. Business Process Manag
# Page usefulness for https://www.facebook.com/archangelmichaelgoc/videos/live/949674730499866/: No
# Extracted context from https://www.odoo.com/th_TH/customers/sostenia-s-r-l-5350747 (first 200 chars): Based on the webpage content, here's the relevant information about Sostenia products and offerings:
#
# Sostenia is a specialized software company focused on digital transformation. Their product and so
# Page usefulness for https://www.dnb.com/business-directory/company-profiles.sostenia_srl.73521df5d458486020c88ff2e136c7a7.html: No
# Extracted context from https://www.odoocompanies.com/c-sostenia-srl (first 200 chars): Sostenia is a software company specializing in digital transformation and business process improvement. Their key technology offerings include:
#
# 1. Odoo implementation (they are an Odoo Gold Partner)
#
# Extracted context from https://heysoteria.com/ (first 200 chars): Based on the webpage content, here are the key details about Sostenia's (Soteria Technology Solutions) products and services:
#
# Services Offerings:
# - Technology Solutions & Managed Services
# - Complianc
# Extracted context from https://www.sostenia.ro/shop (first 200 chars): Based on the webpage content, here are the relevant details about Sostenia products:
#
# Odoo Service Packages:
# 1. Odoo BASIC Package (25 hours) - 1,400.00€
# 2. Odoo STANDARD Package (50 hours) - 2,800.00
# Extracted context from https://www.sostenia.ro/en/aplicatii-software-sostenia (first 200 chars): Based on the webpage content, Sostenia offers the following software products:
#
# 1. TMS Sostenia: A transportation management application that provides visibility into orders and can handle various tra
# Extracted context from https://www.sostenia.ro/en (first 200 chars): Based on the webpage content, here are the key points about Sostenia's products and services:
#
# Sostenia offers digital transformation and business process improvement services, with key offerings incl
# Extracted context from https://www.odoo.com/customers/sostenia-srl-5350747 (first 200 chars): Based on the content, here are the key details about Sostenia's products and services:
#
# Sostenia is a specialized software company focused on digital transformation and enterprise software solutions.
# Page usefulness for https://www.risco.ro/en/verifica-firma/sostenia-cui-35130445?srsltid=AfmBOooisspI3vHrdg4PcklWHcNPpc_vJob_axtkukYudl6vL7GxEdxh: No
# Page usefulness for https://www.emis.com/php/company-profile/RO/Sostenia_SRL_en_14148987.html: Yes
# Page usefulness for https://www.dnb.com/business-directory/company-profiles.sostenia_soc_coop.aff0cc053537f4ca0a02254053f112d4.html: No
# Extracted context from https://www.emis.com/php/company-profile/RO/Sostenia_SRL_en_14148987.html (first 200 chars): Sostenia SRL is a Romanian company in the Information Services industry, founded on October 15, 2015. Key details about their business include:
#
# Industry: Other Information Services
#
# Location: Buchare
# LLM provided new search queries: ['Sostenia software product pricing', 'Sostenia enterprise solution case studies', 'Sostenia digital transformation services client reviews', 'Sostenia technology integration capabilities']
#
# === Iteration 2 ===
# Aggregated 40 unique links from this iteration.
# Fetching content from: https://www.sostenia.ro/en/shop
# Fetching content from: https://www.sostenia.ro/en
# Fetching content from: https://www.odoo.com/customers/sostenia-srl-5350747
# Fetching content from: https://amazon.jobs/it/jobs/2962084/software-development-manager-pricing-shared-services
# Fetching content from: https://www.pricefx.com/learning-center/the-5-types-of-pricing-software
# Fetching content from: https://www.amazon.jobs/it/jobs/2994841/software-development-manager-ab-pricing
# Fetching content from: https://www.youtube.com/watch?v=LCEmiRjPEtQ
# Fetching content from: https://www.saasacademy.com/blog/saas-pricing-strategies
# Fetching content from: https://www.linkedin.com/posts/sostenia_salesrepresentative-salesopening-activity-7289938221893877761-WVrL
# Fetching content from: https://holidaygolf.com/?b=92971247021100&mod=d5c60496&uri=shared.php%3Fid%3D3107083-1186%26name%3Dbody+perizoma+modellante
# Fetching content from: https://www.youtube.com/watch?v=KYDFLOjBPLY
# Fetching content from: https://www.sosi.com/case-studies/
# Fetching content from: https://www.cognizant.com/us/en/case-studies
# Fetching content from: https://www.renewablethermal.org/category/publications/case-studies/
# Fetching content from: https://www.mrisoftware.com/resources/enterprise-community-partners-case-study/
# Fetching content from: https://soti.net/resources/case-studies/
# Fetching content from: https://www.randstadenterprise.com/insights/case-studies/
# Fetching content from: https://www.sygnia.co/case-study/
# Fetching content from: https://www.exelatech.com/case-studies
# Fetching content from: https://www.ibm.com/case-studies
# Fetching content from: https://firstpagesage.com/business/the-top-digital-transformation-agencies-in-the-us/
# Fetching content from: https://www.quora.com/Which-is-the-best-company-for-digital-transformation-consulting-services-and-solutions
# Fetching content from: https://www.smartosc.com/digital-transformation-services-companies/
# Fetching content from: https://quixy.com/blog/examples-of-digital-transformation/
# Fetching content from: https://www.mantech.com/focus-areas/digital-transformation-strategy/
# Fetching content from: https://www.imaginarycloud.com/blog/top-digital-transformation-companies
# Fetching content from: https://www.canidium.com/blog/digital-transformation-services-worth-it-comprehensive-cost-benefit-analysis
# Fetching content from: https://diceus.com/how-to-transform-business-with-digital-transformation-consulting/
# Fetching content from: https://enterprisersproject.com/what-is-digital-transformation
# Fetching content from: https://www.amazon.com/Digital-Transformation-Success-Achieving-Delivering/dp/1484298152
# Fetching content from: https://www.darpa.mil/research/programs/system-of-systems-integration-technology-and-experimentation
# Fetching content from: https://safetyiq.com/insight/what-does-technology-integration-mean/
# Fetching content from: https://www.edutopia.org/technology-integration-guide-description
# Fetching content from: https://fcit.usf.edu/matrix/
# Fetching content from: https://nces.ed.gov/pubs2003/tech_schools/chapter7.asp
# Fetching content from: https://www.ornl.gov/group/technology-integration
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S004016252100367X
# Fetching content from: https://sstech.us/
# Fetching content from: https://advisorservices.schwab.com/managing-your-business/tech-integration
# Fetching content from: https://www.mckinsey.com/capabilities/mckinsey-digital/our-insights/toward-an-integrated-technology-operating-model
# Page usefulness for https://www.youtube.com/watch?v=KYDFLOjBPLY: No
# Page usefulness for https://www.odoo.com/customers/sostenia-srl-5350747: Yes
# Page usefulness for https://www.sostenia.ro/en: Yes
# Page usefulness for https://www.imaginarycloud.com/blog/top-digital-transformation-companies: No
# Page usefulness for https://www.linkedin.com/posts/sostenia_salesrepresentative-salesopening-activity-7289938221893877761-WVrL: No
# Page usefulness for https://www.amazon.com/Digital-Transformation-Success-Achieving-Delivering/dp/1484298152: No
# Page usefulness for https://nces.ed.gov/pubs2003/tech_schools/chapter7.asp: No
# Page usefulness for https://www.mrisoftware.com/resources/enterprise-community-partners-case-study/: No
# Page usefulness for https://www.smartosc.com/digital-transformation-services-companies/: No
# Page usefulness for https://advisorservices.schwab.com/managing-your-business/tech-integration: No
# Page usefulness for https://www.amazon.jobs/it/jobs/2994841/software-development-manager-ab-pricing: No
# Page usefulness for https://www.pricefx.com/learning-center/the-5-types-of-pricing-software: No
# Page usefulness for https://www.quora.com/Which-is-the-best-company-for-digital-transformation-consulting-services-and-solutions: No
# Page usefulness for https://www.ornl.gov/group/technology-integration: No
# Page usefulness for https://diceus.com/how-to-transform-business-with-digital-transformation-consulting/: No
# Page usefulness for https://amazon.jobs/it/jobs/2962084/software-development-manager-pricing-shared-services: No
# Page usefulness for https://www.exelatech.com/case-studies: No
# Page usefulness for https://enterprisersproject.com/what-is-digital-transformation: No
# Page usefulness for https://www.mantech.com/focus-areas/digital-transformation-strategy/: No
# Page usefulness for https://quixy.com/blog/examples-of-digital-transformation/: No
# Page usefulness for https://www.renewablethermal.org/category/publications/case-studies/: No
# Page usefulness for https://soti.net/resources/case-studies/: No
# Page usefulness for https://www.darpa.mil/research/programs/system-of-systems-integration-technology-and-experimentation: No
# Page usefulness for https://www.edutopia.org/technology-integration-guide-description: No
# Page usefulness for https://www.youtube.com/watch?v=LCEmiRjPEtQ: No
# Page usefulness for https://firstpagesage.com/business/the-top-digital-transformation-agencies-in-the-us/: No
# Page usefulness for https://www.mckinsey.com/capabilities/mckinsey-digital/our-insights/toward-an-integrated-technology-operating-model: No
# Extracted context from https://www.odoo.com/customers/sostenia-srl-5350747 (first 200 chars): Based on the content, here are the key details about Sostenia products:
#
# Sostenia is a specialized software company focused on digital transformation. Their product portfolio includes:
#
# 1. ERP Systems
# Page usefulness for https://www.canidium.com/blog/digital-transformation-services-worth-it-comprehensive-cost-benefit-analysis: No
# Page usefulness for https://holidaygolf.com/?b=92971247021100&mod=d5c60496&uri=shared.php%3Fid%3D3107083-1186%26name%3Dbody+perizoma+modellante: No
# Extracted context from https://www.sostenia.ro/en (first 200 chars): Based on the webpage content, here are the relevant details about Sostenia's products and services:
#
# Sostenia offers digital transformation and software solutions, focusing on:
#
# 1. Business Process Ma
# Page usefulness for https://safetyiq.com/insight/what-does-technology-integration-mean/: No
# Page usefulness for https://www.sostenia.ro/en/shop: Yes
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S004016252100367X: No
# Page usefulness for https://www.randstadenterprise.com/insights/case-studies/: No
# Extracted context from https://www.sostenia.ro/en/shop (first 200 chars): Based on the webpage content, here are the relevant details about Sostenia products:
#
# Odoo Software Packages (Pricing):
#
# 1. Odoo BASIC Package (25 hours)
# - Price: 1,400.00 EUR
#
# 2. Odoo STANDARD Packag
# Page usefulness for https://www.saasacademy.com/blog/saas-pricing-strategies: No
# Page usefulness for https://www.sosi.com/case-studies/: No
# Page usefulness for https://www.ibm.com/case-studies: No
# Page usefulness for https://sstech.us/: No
# Page usefulness for https://www.cognizant.com/us/en/case-studies: No
# Page usefulness for https://www.sygnia.co/case-study/: No
# Page usefulness for https://fcit.usf.edu/matrix/: No
# LLM provided new search queries: ['Sostenia software pricing comparison', 'Sostenia integration case studies', 'Sostenia client testimonials', 'Sostenia technology partnerships']
#
# Generating final report...
#
# ==== FINAL REPORT ====
#
# Comprehensive Analysis of Sostenia Products
#
# Executive Summary:
# Sostenia is a specialized digital transformation software company with over 18 years of experience, offering a comprehensive suite of enterprise software solutions, process automation technologies, and custom software development services.
#
# Product Portfolio:
#
# 1. Enterprise Resource Planning (ERP) Systems
# - Odoo ERP (Gold Partner)
# - SAP ERP Systems
# - Pricing Packages:
#   * BASIC: 25 hours - €1,400
#   * STANDARD: 50 hours - €2,800
#   * BUSINESS: 75 hours - €4,200
#   * PREMIUM: 100 hours - €5,600
#
# 2. Process Automation Technologies
# - UiPath Robotic Process Automation (RPA)
# - DRUID Intelligent ChatBots
# - Advanced workflow integration capabilities
#
# 3. Custom Software Solutions
# a) Management Systems:
# - Transportation Management System (TMS)
# - Document Management System (DMS)
# - Customer Relationship Management (CRM)
# - Warehouse Management System (WMS)
# - Stock Keeping Unit (SKU) Management
#
# b) Additional Platforms:
# - FieldOS
# - ContentSpeed E-commerce Platform
# - Business Intelligence (BI) Systems
# - Web Services (WS)
#
# Key Technological Capabilities:
# - Cross-platform accessibility
# - Enhanced security
# - Intelligent algorithm integration
# - Workflow automation
# - Customizable enterprise solutions
#
# Company Performance Metrics:
# - 50+ companies served
# - 8,000+ man-days saved through automation annually
# - 150+ business processes analyzed yearly
# - 55+ specialized digital transformation consultants
#
# Competitive Advantages:
# - Odoo Gold Partner status
# - Best Starter Europe award (2022)
# - Mature, internationally recognized solutions
# - End-to-end implementation services
# - Flexible business consultancy
#
# Target Industries:
# - Manufacturing
# - Healthcare
# - Public Sector
# - Various enterprise-level organizations
#
# Conclusion:
# Sostenia offers a robust, versatile suite of digital transformation products and services, emphasizing technological integration, process optimization, and customized enterprise solutions across multiple industries.
#
# Recommendations:
# 1. Potential clients should evaluate specific package offerings aligned with their digital transformation needs
# 2. Organizations seeking comprehensive process automation should consider Sostenia's integrated technological approach
# 3. Businesses should leverage Sostenia's consultation services for tailored digital strategy development
